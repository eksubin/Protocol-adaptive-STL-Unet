# %%
import os
import numpy as np
print(os.getcwd())
import skimage.io as io
import glob
import nrrd
# Out:
# /home/erattakulangara/hpchome/DeepLearningAlgo/2022-Protocol-Adaptive_multiArtSegmentation

# %%
filename = './data/chest_x_ray/raw/chestCT-sample/label.nrrd'
image = './data/chest_x_ray/raw/chestCT-sample/image.nrrd'
data, header = nrrd.read(image)

import matplotlib.pyplot as plt
data.shape
# Out:
# (512, 512, 136)

# %%
plt.imshow(data[:,:,50])
#plt.imsave('annot.png',data[:,:,100], cmap='gray')

# %%
data_root = './data/chest_x_ray/raw/seg-lungs-LUNA16/seg-lungs-LUNA16/*'
annotation = './data/chest_x_ray/raw/annotations.csv'

# %%
print(len(glob.glob(data_root)))
# Out:
# 1776

# %%
file = './data/chest_x_ray/raw/seg-lungs-LUNA16/seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.216652640878960522552873394709.mhd'
img = io.imread(file, plugin='simpleitk')

# %%
img.shape
# Out:
# (103, 512, 512)

# %%
import matplotlib.pyplot as plt
plt.imshow(img[80,:,:])

# %%
import pandas as pd
data = pd.read_csv(annotation)

# %%
data.head()
# Out:
#                                            seriesuid      coordX      coordY  \
# 0  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222... -128.699421 -175.319272
# 1  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  103.783651 -211.925149
# 2  1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793...   69.639017 -140.944586
# 3  1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...  -24.013824  192.102405
# 4  1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...    2.441547  172.464881
#
#        coordZ  diameter_mm
# 0 -298.387506     5.651471
# 1 -227.121250     4.224708
# 2  876.374496     5.786348
# 3 -391.081276     8.143262
# 4 -405.493732    18.545150
